# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('../DataSplit/SentenceSplit/split_data1.csv')

df.head()
# Out:
#                                         PageURL           Title  \
# 0  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 1  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 2  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 3  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 4  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
#
#            CreationDate Seccion Subseccion  WikipageID          LastModified  \
# 0  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 1  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 2  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 3  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 4  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
#
#                                                split  split_id  tokens
# ...

# %%
# Set the figure size
plt.figure(figsize=(8, 6))

# Customize the style of the plot
sns.set(style="whitegrid")

# Create a histogram using Seaborn
sns.histplot(data=df['tokens'], kde=True, color='blue')

# Set the title
plt.title("Histograma de Tokens (Sentence, 1)")

# Show the histogram
plt.show()

# %%
df_prueba = pd.read_csv('C:\\Users\\sotof\\OneDrive - Universidad Técnica Particular de Loja - UTPL\\NOVENO\\Tesis\\tesis-qa-system\\DataSplits\\dominioFinalSpliteado2.csv')

#df_prueba.head()
# Set the figure size
plt.figure(figsize=(8, 6))

# Customize the style of the plot
sns.set(style="whitegrid")

# Create a histogram using Seaborn
sns.histplot(data=df_prueba['tokens'], kde=True, color='blue')

# Set the title
plt.title("Histograma de Tokens (Sentence, 2) NUEVO")

# Show the histogram
plt.show()

# %%
df_prueba.shape
# Out:
# (57692, 12)

# %%
df = pd.read_csv('../DataSplit/SentenceSplit/split_data1.csv')

df.head()
# Out:
#                                         PageURL           Title  \
# 0  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 1  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 2  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 3  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 4  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
#
#            CreationDate Seccion Subseccion  WikipageID          LastModified  \
# 0  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 1  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 2  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 3  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 4  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
#
#                                                split  split_id  tokens
# ...

# %%
# Set the figure size
plt.figure(figsize=(8, 6))

# Customize the style of the plot
sns.set(style="whitegrid")

# Create a histogram using Seaborn
sns.histplot(data=df['tokens'], kde=True, color='blue')

# Set the title
plt.title("Histograma de Tokens (Sentence, 1)")

# Show the histogram
plt.show()

# %%
df = pd.read_csv('../DataSplit/SentenceSplit/split_data2.csv')

df.head()
# Out:
#                                         PageURL           Title  \
# 0  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 1  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 2  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 3  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 4  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
#
#            CreationDate Seccion Subseccion  WikipageID          LastModified  \
# 0  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 1  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 2  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 3  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 4  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
#
#                                                split  split_id  tokens
# ...

# %%
df_prueba_2 = pd.read_csv('../DataSplit/SentenceSplit/split_data_sentence_2total.csv')

#df_prueba_2.head()
# Set the figure size
plt.figure(figsize=(8, 6))

# Customize the style of the plot
sns.set(style="whitegrid")

# Create a histogram using Seaborn
sns.histplot(data=df_prueba_2['tokens'], kde=True, color='blue')

# Set the title
plt.title("Histograma de Tokens (Sentence, 2)")

# Show the histogram
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(8, 6))

# Customize the style of the plot
sns.set(style="whitegrid")

# Create a histogram using Seaborn
sns.histplot(data=df['tokens'], kde=True, color='blue')

# Set the title
plt.title("Histograma de Tokens (Sentence, 2)")

# Show the histogram
plt.show()

# %%
df = pd.read_csv('../DataSplit/SentenceSplit/split_data3.csv')

df.head()
# Out:
#                                         PageURL           Title  \
# 0  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 1  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 2  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 3  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 4  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
#
#            CreationDate Seccion Subseccion  WikipageID          LastModified  \
# 0  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 1  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 2  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 3  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 4  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
#
#                                                split  split_id  tokens
# ...

# %%
# Set the figure size
plt.figure(figsize=(8, 6))

# Customize the style of the plot
sns.set(style="whitegrid")

# Create a histogram using Seaborn
sns.histplot(data=df['tokens'], kde=True, color='blue')

# Set the title
plt.title("Histograma de Tokens (Sentence, 3)")

# Show the histogram
plt.show()

# %%
df = pd.read_csv('../DataSplit/SentenceSplit/split_data4.csv')

df.head()
# Out:
#                                         PageURL           Title  \
# 0  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 1  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 2  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 3  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 4  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
#
#            CreationDate Seccion Subseccion  WikipageID          LastModified  \
# 0  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 1  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 2  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 3  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
# 4  2023-09-25T06:26:03Z     NaN        NaN        5906  2023-09-25T06:26:03Z
#
#                                                split  split_id  tokens
# ...

# %%
# Set the figure size
plt.figure(figsize=(8, 6))

# Customize the style of the plot
sns.set(style="whitegrid")

# Create a histogram using Seaborn
sns.histplot(data=df['tokens'], kde=True, color='blue')

# Set the title
plt.title("Histograma de Tokens (Sentence, 4)")

# Show the histogram
plt.show()

# %%
df = pd.read_csv('../DataSplit/SentenceSplit/split_data5.csv')

df.head()
# Out:
#                                         PageURL           Title  \
# 0  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 1  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 2  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 3  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
# 4  https://en.wikipedia.org/wiki/Carbon_dioxide  Carbon dioxide
#
#            CreationDate                             Seccion  \
# 0  2023-09-25T06:26:03Z                                 NaN
# 1  2023-09-25T06:26:03Z                                 NaN
# 2  2023-09-25T06:26:03Z                                 NaN
# 3  2023-09-25T06:26:03Z                                 NaN
# 4  2023-09-25T06:26:03Z   Chemical and physical properties
#
#                                       Subseccion  WikipageID  \
# 0                                            NaN        5906
# 1                                            NaN        5906
# ...

# %%
# Set the figure size
plt.figure(figsize=(8, 6))

# Customize the style of the plot
sns.set(style="whitegrid")

# Create a histogram using Seaborn
sns.histplot(data=df['tokens'], kde=True, color='blue')

# Set the title
plt.title("Histograma de Tokens (Sentence, 5) OLD")

# Show the histogram
plt.show()

# %%
df.shape
# Out:
# (100222, 10)

# %%
df_1 = pd.read_csv('C:\\Users\\sotof\\OneDrive - Universidad Técnica Particular de Loja - UTPL\\NOVENO\\Tesis\\tesis-qa-system\\DataSplits\\dominioFinalSpliteado1.csv')

df_2 = pd.read_csv('C:\\Users\\sotof\\OneDrive - Universidad Técnica Particular de Loja - UTPL\\NOVENO\\Tesis\\tesis-qa-system\\DataSplits\\dominioFinalSpliteado2.csv')

df_3 = pd.read_csv('C:\\Users\\sotof\\OneDrive - Universidad Técnica Particular de Loja - UTPL\\NOVENO\\Tesis\\tesis-qa-system\\DataSplits\\dominioFinalSpliteado3.csv')

df_4 = pd.read_csv('C:\\Users\\sotof\\OneDrive - Universidad Técnica Particular de Loja - UTPL\\NOVENO\\Tesis\\tesis-qa-system\\DataSplits\\dominioFinalSpliteado4.csv')

df_5 = pd.read_csv('C:\\Users\\sotof\\OneDrive - Universidad Técnica Particular de Loja - UTPL\\NOVENO\\Tesis\\tesis-qa-system\\DataSplits\\dominioFinalSpliteado5.csv')

df_6 = pd.read_csv('C:\\Users\\sotof\\OneDrive - Universidad Técnica Particular de Loja - UTPL\\NOVENO\\Tesis\\tesis-qa-system\\DataSplits\\dominioFinalSpliteado6.csv')

df_7 = pd.read_csv('C:\\Users\\sotof\\OneDrive - Universidad Técnica Particular de Loja - UTPL\\NOVENO\\Tesis\\tesis-qa-system\\DataSplits\\dominioFinalSpliteado7.csv')

df_8 = pd.read_csv('C:\\Users\\sotof\\OneDrive - Universidad Técnica Particular de Loja - UTPL\\NOVENO\\Tesis\\tesis-qa-system\\DataSplits\\dominioFinalSpliteado.csv')


# Set the figure size
plt.figure(figsize=(15, 8))  # Adjust the figure size to accommodate all subplots

# Customize the style of the plot
sns.set(style="whitegrid")

# Create subplots for histograms of each DataFrame
plt.subplot(2, 4, 1)
sns.histplot(data=df_1['tokens'], kde=True, color='blue')
plt.title("Histogram - Sentences / 1")

plt.subplot(2, 4, 2)
sns.histplot(data=df_2['tokens'], kde=True, color='orange')
plt.title("Histogram - Sentences / 2")

plt.subplot(2, 4, 3)
sns.histplot(data=df_3['tokens'], kde=True, color='green')
plt.title("Histogram - Sentences / 3")

plt.subplot(2, 4, 4)
sns.histplot(data=df_4['tokens'], kde=True, color='red')
plt.title("Histogram - Sentences / 4")

plt.subplot(2, 4, 5)
sns.histplot(data=df_5['tokens'], kde=True, color='purple')
plt.title("Histogram - Sentences / 5")

plt.subplot(2, 4, 6)
sns.histplot(data=df_6['tokens'], kde=True, color='purple')
plt.title("Histogram - Sentences / 6")

plt.subplot(2, 4, 7)
sns.histplot(data=df_7['tokens'], kde=True, color='purple')
plt.title("Histogram - Sentences / 7")


plt.subplot(2, 4, 8)
sns.histplot(data=df_8['tokens'], kde=True, color='purple')
plt.title("Histogram - Sentences / Data Final Spliteado")

plt.tight_layout()

# Show the histograms
plt.show()
